# %%
import sys
sys.path.append(r"C:\Users\siddh\automatic-outlier-detection")

# %%
import pandas as pd

# %%
from src.linear_regression_utils import load_dataset
from src.outlier_detection import AutomaticOutlierDetection

# %%
data = load_dataset()

# %%
outlier_detector = AutomaticOutlierDetection()

# %%
adjusted_model = outlier_detector.fit_and_detect_outliers(data, target_column="target")

# %%
outlier_detector.plot_results(data, target_column="target")
